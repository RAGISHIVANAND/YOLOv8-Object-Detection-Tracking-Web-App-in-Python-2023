# %% [markdown]
# <a href="https://colab.research.google.com/github/RAGISHIVANAND/YOLOv8-Object-Detection-Tracking-Web-App-in-Python-2023/blob/main/yolov8_implementation_in_google_colabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***`Import the required library`***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from IPython.display import Image

# %% [markdown]
# # ***`Install ultralytics library`***

# %%
# !pip install ultralytics==8.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 17.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.3 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=f56c8fa8c1dd636c6bd40098e5f2474fc44b2f27b9f38df07327d67dfe91b311
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# ...

# %% [markdown]
# # ***Check whether the GPU is Available or Not***

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.1.0+cu121'

# %% [markdown]
# # ***Object Detection***

# %% [markdown]
# Run object detection as a sample image

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/drive/MyDrive/google colab  files/image1.jpg'
# Out:
# 2023-12-28 16:36:31.364702: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-28 16:36:31.364775: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-28 16:36:31.366318: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-28 16:36:32.399531: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
# 100% 21.5M/21.5M [00:00<00:00, 180MB/s]
#
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# ...

# %% [markdown]
# # ***Display the output Image***

# %%
Image('/content/runs/detect/predict/image1.jpg')

# %% [markdown]
# # ***To save the Bounding Box information set save_txt=True***

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/drive/MyDrive/google colab  files/image1.jpg' save_txt=True
# Out:
# 2023-12-28 17:11:28.892784: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-28 17:11:28.892859: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-28 17:11:28.894963: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-28 17:11:30.391361: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# ...

# %% [markdown]
# # ***Display the output Image***

# %%
Image('/content/runs/detect/predict2/image1.jpg')

# %% [markdown]
# # ***To save the"crop object " set save_crop=True***

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/drive/MyDrive/google colab  files/image1.jpg' save_crop=True
# Out:
# 2023-12-28 17:45:59.636413: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-28 17:45:59.636473: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-28 17:45:59.637874: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-28 17:46:00.718758: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# ...

# %% [markdown]
# # ***Display the output image***

# %%
Image('/content/runs/detect/predict3/crops/person/image16.jpg')
